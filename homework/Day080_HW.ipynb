# %% [markdown]
# # 請結合前面的知識與程式碼，比較不同的 optimizer 與 learning rate 組合對訓練的結果與影響
# ### 常見的 optimizer 包含
# * SGD
# * RMSprop
# * AdaGrad
# * Adam

# %%
import os
import keras
import itertools 
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
"""
Set your required experiment parameters
"""
LEARNING_RATE = [1e-1, 1e-3, 1e-5]
EPOCHS = 5
BATCH_SIZE = 256
OPTIMIZER = [keras.optimizers.SGD, keras.optimizers.RMSprop, keras.optimizers.Adagrad, keras.optimizers.Adam]

# %%
results = {}
"""
建立訓練與實驗迴圈並蒐集資料
"""
for lr, opt in itertools.product(LEARNING_RATE, OPTIMIZER):
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with LR = %.6f, Optimizer = %s" % (lr, str(opt)))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    
    optimizer = opt(lr=lr)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["accuracy"]
    valid_acc = model.history.history["val_accuracy"]
    
    exp_name_tag = "exp-lr-%s-optimizer-%s" % (str(lr), str(opt))
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with LR = 0.100000, Optimizer = <class 'keras.optimizers.SGD'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 37s 741us/step - loss: 2.0394 - accuracy: 0.2562 - val_loss: 1.8964 - val_accuracy: 0.3054
# Epoch 2/5
# 50000/50000 [==============================] - 11s 225us/step - loss: 1.8191 - accuracy: 0.3456 - val_loss: 1.8498 - val_accuracy: 0.3321
# Epoch 3/5
# 50000/50000 [==============================] - 12s 242us/step - loss: 1.7320 - accuracy: 0.3807 - val_loss: 1.7731 - val_accuracy: 0.3773
# Epoch 4/5
# 50000/50000 [==============================] - 12s 244us/step - loss: 1.6724 - accuracy: 0.4020 - val_loss: 1.7419 - val_accuracy: 0.3842
# Epoch 5/5
# 50000/50000 [==============================] - 12s 236us/step - loss: 1.6157 - accuracy: 0.4247 - val_loss: 1.5872 - val_accuracy: 0.4375
# Experiment with LR = 0.100000, Optimizer = <class 'keras.optimizers.RMSprop'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 15s 294us/step - loss: 25961.6915 - accuracy: 0.0996 - val_loss: 2.3162 - val_accuracy: 0.1000
# Epoch 2/5
# 50000/50000 [==============================] - 14s 290us/step - loss: 288.4749 - accuracy: 0.0997 - val_loss: 2.3448 - val_accuracy: 0.1000
# Epoch 3/5
# 50000/50000 [==============================] - 14s 290us/step - loss: 62.4895 - accuracy: 0.0986 - val_loss: 2.3218 - val_accuracy: 0.1000
# Epoch 4/5
# 50000/50000 [==============================] - 15s 294us/step - loss: 2.3073 - accuracy: 0.1013 - val_loss: 2.3246 - val_accuracy: 0.1000
# Epoch 5/5
# 50000/50000 [==============================] - 15s 293us/step - loss: 2.3080 - accuracy: 0.0979 - val_loss: 2.3104 - val_accuracy: 0.1000
# Experiment with LR = 0.100000, Optimizer = <class 'keras.optimizers.Adagrad'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 14s 283us/step - loss: 422.0847 - accuracy: 0.0987 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 2/5
# 50000/50000 [==============================] - 14s 279us/step - loss: 2.3028 - accuracy: 0.0989 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 3/5
# 50000/50000 [==============================] - 14s 280us/step - loss: 2.3028 - accuracy: 0.0993 - val_loss: 2.3029 - val_accuracy: 0.1000
# Epoch 4/5
# 50000/50000 [==============================] - 14s 281us/step - loss: 2.3029 - accuracy: 0.0981 - val_loss: 2.3027 - val_accuracy: 0.1000
# Epoch 5/5
# 50000/50000 [==============================] - 14s 282us/step - loss: 2.3028 - accuracy: 0.1013 - val_loss: 2.3027 - val_accuracy: 0.1000
# Experiment with LR = 0.100000, Optimizer = <class 'keras.optimizers.Adam'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 18s 365us/step - loss: 140.2935 - accuracy: 0.0978 - val_loss: 2.4427 - val_accuracy: 0.1000
# Epoch 2/5
# 50000/50000 [==============================] - 17s 336us/step - loss: 2.3302 - accuracy: 0.0989 - val_loss: 2.4316 - val_accuracy: 0.1000
# Epoch 3/5
# 50000/50000 [==============================] - 17s 340us/step - loss: 2.3100 - accuracy: 0.1005 - val_loss: 2.4320 - val_accuracy: 0.1000
# Epoch 4/5
# 50000/50000 [==============================] - 18s 352us/step - loss: 2.3055 - accuracy: 0.0967 - val_loss: 2.4317 - val_accuracy: 0.1000
# Epoch 5/5
# 50000/50000 [==============================] - 17s 334us/step - loss: 2.3054 - accuracy: 0.0989 - val_loss: 2.4323 - val_accuracy: 0.1000
# Experiment with LR = 0.001000, Optimizer = <class 'keras.optimizers.SGD'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 11s 226us/step - loss: 2.2701 - accuracy: 0.1566 - val_loss: 2.2235 - val_accuracy: 0.2129
# Epoch 2/5
# 50000/50000 [==============================] - 11s 222us/step - loss: 2.1965 - accuracy: 0.2304 - val_loss: 2.1672 - val_accuracy: 0.2516
# Epoch 3/5
# 50000/50000 [==============================] - 11s 228us/step - loss: 2.1455 - accuracy: 0.2559 - val_loss: 2.1216 - val_accuracy: 0.2673
# Epoch 4/5
# 50000/50000 [==============================] - 12s 233us/step - loss: 2.1025 - accuracy: 0.2717 - val_loss: 2.0821 - val_accuracy: 0.2738
# Epoch 5/5
# 50000/50000 [==============================] - 11s 226us/step - loss: 2.0654 - accuracy: 0.2820 - val_loss: 2.0479 - val_accuracy: 0.2894
# Experiment with LR = 0.001000, Optimizer = <class 'keras.optimizers.RMSprop'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 14s 288us/step - loss: 2.2792 - accuracy: 0.2105 - val_loss: 1.9824 - val_accuracy: 0.2868
# Epoch 2/5
# 50000/50000 [==============================] - 14s 281us/step - loss: 1.8925 - accuracy: 0.3156 - val_loss: 1.8963 - val_accuracy: 0.3330
# Epoch 3/5
# 50000/50000 [==============================] - 14s 284us/step - loss: 1.7853 - accuracy: 0.3598 - val_loss: 1.7505 - val_accuracy: 0.3698
# Epoch 4/5
# 50000/50000 [==============================] - 14s 283us/step - loss: 1.7147 - accuracy: 0.3840 - val_loss: 1.7666 - val_accuracy: 0.3611
# Epoch 5/5
# 50000/50000 [==============================] - 14s 285us/step - loss: 1.6606 - accuracy: 0.4063 - val_loss: 1.7641 - val_accuracy: 0.3759
# Experiment with LR = 0.001000, Optimizer = <class 'keras.optimizers.Adagrad'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 14s 272us/step - loss: 2.0086 - accuracy: 0.2765 - val_loss: 1.8828 - val_accuracy: 0.3405
# Epoch 2/5
# 50000/50000 [==============================] - 13s 269us/step - loss: 1.8153 - accuracy: 0.3597 - val_loss: 1.8125 - val_accuracy: 0.3551
# Epoch 3/5
# 50000/50000 [==============================] - 13s 268us/step - loss: 1.7425 - accuracy: 0.3873 - val_loss: 1.7300 - val_accuracy: 0.3900
# Epoch 4/5
# 50000/50000 [==============================] - 13s 267us/step - loss: 1.6903 - accuracy: 0.4049 - val_loss: 1.6783 - val_accuracy: 0.4102
# Epoch 5/5
# 50000/50000 [==============================] - 14s 270us/step - loss: 1.6533 - accuracy: 0.4192 - val_loss: 1.6602 - val_accuracy: 0.4209
# Experiment with LR = 0.001000, Optimizer = <class 'keras.optimizers.Adam'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 17s 344us/step - loss: 1.9237 - accuracy: 0.3030 - val_loss: 1.7689 - val_accuracy: 0.3517
# Epoch 2/5
# 50000/50000 [==============================] - 16s 321us/step - loss: 1.7119 - accuracy: 0.3859 - val_loss: 1.7036 - val_accuracy: 0.3883
# Epoch 3/5
# 50000/50000 [==============================] - 16s 327us/step - loss: 1.6413 - accuracy: 0.4155 - val_loss: 1.6055 - val_accuracy: 0.4227
# Epoch 4/5
# 50000/50000 [==============================] - 17s 347us/step - loss: 1.5557 - accuracy: 0.4430 - val_loss: 1.5956 - val_accuracy: 0.4354
# Epoch 5/5
# 50000/50000 [==============================] - 16s 328us/step - loss: 1.5075 - accuracy: 0.4635 - val_loss: 1.5160 - val_accuracy: 0.4575
# Experiment with LR = 0.000010, Optimizer = <class 'keras.optimizers.SGD'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 12s 234us/step - loss: 2.3487 - accuracy: 0.0971 - val_loss: 2.3467 - val_accuracy: 0.0996
# Epoch 2/5
# 50000/50000 [==============================] - 12s 246us/step - loss: 2.3426 - accuracy: 0.0990 - val_loss: 2.3410 - val_accuracy: 0.0987
# Epoch 3/5
# 50000/50000 [==============================] - 13s 253us/step - loss: 2.3372 - accuracy: 0.1008 - val_loss: 2.3360 - val_accuracy: 0.1004
# Epoch 4/5
# 50000/50000 [==============================] - 12s 248us/step - loss: 2.3324 - accuracy: 0.1028 - val_loss: 2.3315 - val_accuracy: 0.1022
# Epoch 5/5
# 50000/50000 [==============================] - 12s 239us/step - loss: 2.3281 - accuracy: 0.1051 - val_loss: 2.3274 - val_accuracy: 0.1054
# Experiment with LR = 0.000010, Optimizer = <class 'keras.optimizers.RMSprop'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 14s 280us/step - loss: 2.1252 - accuracy: 0.2556 - val_loss: 2.0097 - val_accuracy: 0.3063
# Epoch 2/5
# 50000/50000 [==============================] - 14s 281us/step - loss: 1.9542 - accuracy: 0.3224 - val_loss: 1.9097 - val_accuracy: 0.3349
# Epoch 3/5
# 50000/50000 [==============================] - 14s 287us/step - loss: 1.8800 - accuracy: 0.3480 - val_loss: 1.8538 - val_accuracy: 0.3609
# Epoch 4/5
# 50000/50000 [==============================] - 14s 287us/step - loss: 1.8330 - accuracy: 0.3636 - val_loss: 1.8189 - val_accuracy: 0.3636
# Epoch 5/5
# 50000/50000 [==============================] - 14s 284us/step - loss: 1.7989 - accuracy: 0.3766 - val_loss: 1.7931 - val_accuracy: 0.3757
# Experiment with LR = 0.000010, Optimizer = <class 'keras.optimizers.Adagrad'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 13s 267us/step - loss: 2.2654 - accuracy: 0.1559 - val_loss: 2.2322 - val_accuracy: 0.1773
# Epoch 2/5
# 50000/50000 [==============================] - 14s 272us/step - loss: 2.2189 - accuracy: 0.1908 - val_loss: 2.2047 - val_accuracy: 0.1987
# Epoch 3/5
# 50000/50000 [==============================] - 13s 269us/step - loss: 2.1965 - accuracy: 0.2048 - val_loss: 2.1856 - val_accuracy: 0.2106
# Epoch 4/5
# 50000/50000 [==============================] - 13s 265us/step - loss: 2.1794 - accuracy: 0.2171 - val_loss: 2.1700 - val_accuracy: 0.2218
# Epoch 5/5
# 50000/50000 [==============================] - 13s 268us/step - loss: 2.1648 - accuracy: 0.2280 - val_loss: 2.1566 - val_accuracy: 0.2302
# Experiment with LR = 0.000010, Optimizer = <class 'keras.optimizers.Adam'>
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/5
# 50000/50000 [==============================] - 16s 324us/step - loss: 2.1330 - accuracy: 0.2497 - val_loss: 1.9987 - val_accuracy: 0.3085
# Epoch 2/5
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.9326 - accuracy: 0.3298 - val_loss: 1.8845 - val_accuracy: 0.3456
# Epoch 3/5
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.8490 - accuracy: 0.3578 - val_loss: 1.8253 - val_accuracy: 0.3622
# Epoch 4/5
# 50000/50000 [==============================] - 16s 325us/step - loss: 1.7986 - accuracy: 0.3750 - val_loss: 1.7815 - val_accuracy: 0.3749
# Epoch 5/5
# 50000/50000 [==============================] - 16s 320us/step - loss: 1.7639 - accuracy: 0.3879 - val_loss: 1.7512 - val_accuracy: 0.3865

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

"""
將實驗結果繪出
"""
NUM_COLORS = len(results.keys())
cm = plt.get_cmap('gist_rainbow')
color_bar = [cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
