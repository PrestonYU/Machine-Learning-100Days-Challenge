# %% [markdown]
# # 作業
# * 試著想想看, 非監督學習是否有可能使用評價函數 (Metric) 來鑑別好壞呢?
# (Hint : 可以分為 "有目標值" 與 "無目標值" 兩個方向思考)

# %% [markdown]
# 非監督學習的輸出結果好壞比較主觀，較不容易用評價函數來鑑別。
#
# 在有目標值的情形下，透過分群的話有大略的好壞衡量標準；但在無目標值的情形下，判別結果的好壞則會是一個很大的問題。
