# %%
# 載入所有可能套件
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
import copy
from sklearn import metrics, datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, roc_curve
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, OneHotEncoder, Imputer
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import cross_val_score, train_test_split, KFold, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor 
import warnings

# %%
train_data = pd.read_csv('data/train.csv', header=None)
test_data = pd.read_csv('data/test.csv', header=None)
trainLabels_data = pd.read_csv('data/trainLabels.csv', header=None)

train_data.shape, test_data.shape, trainLabels_data.shape
# Out:
# ((1000, 40), (9000, 40), (1000, 1))

# %%
train_data.describe()
# Out:
#                 0            1            2            3            4   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.025596    -0.024526    -0.024088    -0.002271     1.092329
# std       1.008282     1.016298     0.979109     0.970575     4.538834
# min      -3.365711    -3.492086    -2.695602    -3.460471   -16.421901
# 25%      -0.669010    -0.693937    -0.698830    -0.617557    -1.801997
# 50%       0.027895    -0.033194     0.008145     0.002327     0.862818
# 75%       0.762520     0.682753     0.661434     0.640743     3.843172
# max       3.326246     3.583870     2.546507     3.088738    17.565345
#
#                 5            6            7            8            9   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.006250     0.497342    -0.037883     0.026391    -0.003597
# std       0.989128     2.118819     2.232256     1.001064     1.013520
# ...

# %%
test_data.describe()
# Out:
#                 0            1            2            3            4   \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean      0.011814     0.004261    -0.001708     0.008614     1.262429
# std       1.009514     1.011432     0.996685     0.989010     4.527492
# min      -3.568633    -4.238067    -3.587473    -3.646144   -17.296514
# 25%      -0.669886    -0.678792    -0.665240    -0.662560    -1.669099
# 50%       0.006104     0.010758     0.007384     0.009027     1.123982
# 75%       0.703350     0.684755     0.658111     0.683506     4.002391
# max       3.843549     3.538868     3.716102     3.667817    20.551947
#
#                 5            6            7            8            9   \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean      0.006003     0.480585    -0.017228     0.006883    -0.006664
# std       0.999623     2.102394     2.204673     0.989207     0.991570
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(train_data, trainLabels_data, test_size = 0.25, random_state = 402)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((750, 40), (250, 40), (750, 1), (250, 1))

# %%
# Random Forest
rfc_model = RandomForestClassifier(n_estimators = 100, max_depth=10)
rfc_model
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_model.fit(x_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
predicted = rfc_model.predict(test_data)
print(predicted.shape)
predicted
# Out:
# (9000,)
# array([1, 0, 1, ..., 1, 0, 1])

# %%
pd_predicted = pd.DataFrame(predicted)
pd_predicted
# Out:
#       0
# 0     1
# 1     0
# 2     1
# 3     0
# 4     0
# 5     0
# 6     0
# 7     1
# 8     0
# 9     0
# 10    1
# 11    1
# 12    1
# 13    0
# 14    0
# 15    1
# 16    0
# 17    1
# 18    0
# 19    1
# 20    0
# 21    1
# 22    0
# 23    0
# 24    1
# 25    1
# 26    1
# 27    0
# 28    1
# 29    0
# ...  ..
# 8970  1
# 8971  0
# 8972  1
# 8973  0
# 8974  0
# 8975  1
# 8976  0
# 8977  1
# 8978  1
# 8979  1
# 8980  1
# 8981  1
# 8982  1
# 8983  0
# 8984  0
# 8985  1
# 8986  0
# 8987  0
# 8988  1
# 8989  0
# 8990  0
# 8991  0
# 8992  0
# 8993  1
# 8994  1
# 8995  1
# 8996  1
# 8997  1
# 8998  0
# 8999  1
#
# [9000 rows x 1 columns]

# %%
pd_predicted.columns = ['Solution']
pd_predicted['Id'] = np.arange(1, pd_predicted.shape[0]+1)
pd_predicted = pd_predicted[['Id', 'Solution']]
pd_predicted
# Out:
#         Id  Solution
# 0        1         1
# 1        2         0
# 2        3         1
# 3        4         0
# 4        5         0
# 5        6         0
# 6        7         0
# 7        8         1
# 8        9         0
# 9       10         0
# 10      11         1
# 11      12         1
# 12      13         1
# 13      14         0
# 14      15         0
# 15      16         1
# 16      17         0
# 17      18         1
# 18      19         0
# 19      20         1
# 20      21         0
# 21      22         1
# 22      23         0
# 23      24         0
# 24      25         1
# 25      26         1
# 26      27         1
# 27      28         0
# 28      29         1
# 29      30         0
# ...    ...       ...
# 8970  8971         1
# 8971  8972         0
# 8972  8973         1
# 8973  8974         0
# 8974  8975         0
# 8975  8976         1
# 8976  8977         0
# 8977  8978         1
# 8978  8979         1
# 8979  8980         1
# 8980  8981         1
# ...

# %%
pd_predicted.to_csv('Submission_RFC.csv', index=False)
